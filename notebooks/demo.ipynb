# %% [markdown]
# # RAG Conceptual Synthetic Docs
#
# Preview the synthetic document collection used for retrieval.

# %%
from pathlib import Path
    import pandas as pd

    data_path = Path("..") / "data" / "sample_synthetic_data.csv"
    df = pd.read_csv(data_path)
    display(df.head())
    display(df.describe(include="all").transpose().head(12))
    display(df[["doc_id", "title", "text"]])
